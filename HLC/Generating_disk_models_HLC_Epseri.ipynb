# %%
# %load_ext autoreload
# %autoreload 2
# %aimport mcfost
# %matplotlib inline
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib.ticker import LogFormatterExponent
from numpy import unravel_index
import astropy.units as unit
import pysynphot
import os
from sh import gunzip
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
main_dir='/Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Simulations_paper/Revision/HLC_band/'
dust='Astrosil/'
file_dir=main_dir

# %%
par = mcfost.Paramfile(file_dir+'eps_eri_su.para')
print(par)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [146], in <cell line: 1>()
# ----> 1 par = mcfost.Paramfile(file_dir+'eps_eri_su.para')
#       2 print(par)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mcfost-0.3-py3.9.egg/mcfost/paramfiles.py:39, in Paramfile.__init__(self, filename, directory, **kwargs)
#      37 self.filename= filename
#      38 self._directory=directory
# ---> 39 self._readparfile(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mcfost-0.3-py3.9.egg/mcfost/paramfiles.py:103, in Paramfile._readparfile(self, silent, return_text, verbose)
#      75 """
#      76 Read in an MCFOST par file into a dictionary.
#      77
#    (...)
#      90     Return the entire parfile text as an entry in the dict
#      91 """
#      93 #################
#      94 #
#      95 # Warning - the following is pretty ugly code in many places, due to the
#    (...)
#      99 #
#     100 #################
# --> 103 text = open(self.filename,'r').readlines()
#     104 lineptr = 3
#     106 #--- First we define a variety of utility functions to be used below --
#     107 # utility functions for pulling out specific items from a line
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Simulations_paper/Revision/HLC_band/eps_eri_su.para'

# %%
#0.547,0.557,0.567,0.575,0.583,0.593,0.603

# %%
res = mcfost.run_one_file(file_dir+'eps_eri_su.para', wavelengths=[0.547,0.557,0.567,0.575,0.583,0.593,0.603], move_to_subdir=False)
# Out:
# mcfost    : INFO     Running MCFOST for: /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/eps_eri_su.para
# mcfost    : INFO     Computing SED for /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/eps_eri_su.para
# mcfost    : INFO     SED results written to /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/data_th
# mcfost    : INFO     Computing image at 0.547 microns for /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/eps_eri_su.para
# mcfost    : INFO     Computing image at 0.557 microns for /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/eps_eri_su.para
# mcfost    : INFO     Computing image at 0.567 microns for /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/eps_eri_su.para
# mcfost    : INFO     Computing image at 0.575 microns for /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/eps_eri_su.para
# mcfost    : INFO     Computing image at 0.583 microns for /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/eps_eri_su.para
# mcfost    : INFO     Computing image at 0.593 microns for /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/eps_eri_su.para
# mcfost    : INFO     Computing image at 0.603 microns for /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/eps_eri_su.para
# mcfost    : INFO     Calculation complete.

# %%
res = mcfost.run_one_file(file_dir+'eps_eri_su.para', wavelengths=[0.575], move_to_subdir=False)
# Out:
# mcfost    : INFO     Running MCFOST for: /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/eps_eri_su.para
# mcfost    : INFO     Computing SED for /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/eps_eri_su.para
# mcfost    : INFO     SED results written to /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/data_th
# mcfost    : INFO     Computing image at 0.575 microns for /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/eps_eri_su.para
# mcfost    : INFO     Calculation complete.

# %%
model_34 = mcfost.ModelResults(file_dir)
print(model_34)
print(list(model_34._wavelengths_lookup.values()))
model_34.describe()
# Out:
# <MCFOST ModelResults in directory '/Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial'>
# ['0.583', '0.547', '0.557', '0.593', '0.567', '0.575', '0.603']
# Model results in /Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial for eps_eri_su.para
#     Model has 1 inclinations from 34.00000000000001 to 34.00000000000001
#     SED computed from 0.1 - 3000.0 microns using 150 wavelengths
#     Images computed for 7 wavelengths: [0.583 0.547 0.557 0.593 0.567 0.575 0.603] micron

# %%
inc34=model_34.images['0.575']

# %%
px=256
py=256
psf_scale=0.02182 ##arcsecs/pixel
xpix=(np.arange (-px/2, px/2, 1))*psf_scale
ypix=(np.arange (-px/2, px/2, 1))*psf_scale
sq_as_per_pix=psf_scale**2
c=2.99792*10**14
lam=0.575 #in microns#
jy=10**26

# %%
sst_34=np.reshape(inc34.data[5,0],(px,py))
sst_34_jy=(sst_34/c)*(lam)*jy
np.max(sst_34_jy)
# Out:
# 2.599041519555094e-06

# %%
fig=plt.figure(dpi=200)
ax2=plt.subplot(111)
im2=ax2.imshow(sst_34_jy.astype(np.float64)/sq_as_per_pix*1000,
               cmap='gnuplot',extent=[np.min(ypix),np.max(ypix),np.min(xpix),np.max(xpix)])
ax2.invert_yaxis()
ax2.set_ylabel('y [arcsec]')
ax2.set_xlabel('x [arcsec]')
ax2.set_title('Scattered star light-Su: Inclination 34 deg - MCFOST',fontsize=8)
cb=plt.colorbar(im2,orientation='vertical')
cb.set_label("$mJy$/as^2")
#fig.savefig(file_dir+'Su_model_inc75.eps', format='eps', bbox_inches='tight')

# %%
#IR Excess
filename=file_dir+'data_th/sed_rt.fits.gz'
gunzip(filename)
mb=fits.open(file_dir+'data_th/sed_rt.fits')
wavb=mb[1].data
mb_flux=mb[0].data[0]
modelb = pysynphot.ArraySpectrum(wavb, mb_flux.flatten(), name='model_b-spectra',fluxunits='flam',waveunits='microns')
#Star Spectra
star = fits.open(file_dir+'data_th/sed_rt.fits')
wav=star[1].data
star_f=star[0].data[1]
sp = pysynphot.ArraySpectrum(wav, star_f.flatten(), name='Star-spectra',fluxunits='flam',waveunits='microns')
# Out:
# sh.command: INFO     <Command "/usr/bin/gunzip '/Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Trial/data_th/sed_rt.fits.gz'", pid 7823>: process started

# %%
obsflux_dir='/Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-models/Final_Models/'
b5sed=np.genfromtxt(obsflux_dir+"backman_fig_5.csv",delimiter=",")
b5sedinset=np.genfromtxt(obsflux_dir+"backman_fig_5_inset.csv",delimiter=",")

# %%
#Observed flux-Kate Su
obs_ir=np.genfromtxt(obsflux_dir+"EPSERI_wholeSED_measurements.csv",delimiter=",")
obs_wav=obs_ir[5:24,0]
obs_irex=obs_ir[5:24,3]/1000
obs_irerr=obs_ir[5:24,2]/1000

# %%
#irs_measurements
irs_file=np.genfromtxt(obsflux_dir+"EPSERI_IRE_IRS_measurements.csv",delimiter=",")
wav=irs_file[:,0]
irs=irs_file[:,1]/1000
irs_err=irs_file[:,2]/1000

# %%
c=2.99792*10**14
mb_jy=10**26*modelb.flux*modelb.wave/c
st_jy=10**26*sp.flux*sp.wave/c
Irb=mb_jy-st_jy

# %%
fig=plt.figure(figsize=(15,10))
ax2=fig.add_subplot(111)
ax2.yaxis.set_ticks_position('both')
ax2.xaxis.set_ticks_position('both')
ax2.minorticks_on()
ax2.tick_params(which='both', direction='in', width=0.5, labelsize=16)
ax2.semilogx(wav,irs,ls='None',zorder=0)
ax2.errorbar(wav,irs,yerr=irs_err,ls='None',marker='s', mfc='orange',
         mec='orange', ms=5, mew=4,label="Su:Obs IR excess-IRS spectrum", zorder=10)
ax2.errorbar(obs_wav,obs_irex,yerr=obs_irerr,ls='None',marker='s',mfc='purple',mec='purple', ecolor='purple',
         ms=5, mew=4,label="Su:Obs IR excess-Literature",zorder=10)
ax2.semilogx(b5sedinset[:,0],b5sedinset[:,1],".-",label=" Backman--Observed",color="black",zorder=1)
ax2.semilogx(modelb.wave,Irb,label="Su MCFOST model",color="red",zorder=1)
ax2.set_xlim([10,1000])
ax2.set_xlabel('Wavelength (\u03BCm)',fontsize=16)
ax2.set_ylabel('IR Excess (jy)', fontsize=20)
ax2.legend(loc='upper left',fontsize=16)

# %%
#Polarization of the disk
I=np.reshape(inc34.data[0,0],(px,py))
Q=np.reshape(inc34.data[1,0],(px,py))
U=np.reshape(inc34.data[2,0],(px,py))
V=np.reshape(inc34.data[3,0],(px,py))
dst=np.reshape(inc34.data[4,0],(px,py))
sst=np.reshape(inc34.data[5,0],(px,py))
dth=np.reshape(inc34.data[6,0],(px,py))
sth=np.reshape(inc34.data[7,0],(px,py))

# %%
I_jy=(I/c)*(lam)*jy
Q_jy=(Q/c)*(lam)*jy
U_jy=(U/c)*(lam)*jy
V_jy=(V/c)*(lam)*jy
sst_jy=(sst/c)*(lam)*jy

# %%
fig = plt.figure(figsize=(10, 10))
ax1=fig.add_subplot(221)
im1=ax1.imshow(I_jy.astype(np.float64),cmap='plasma',extent=[np.min(ypix),np.max(ypix),np.min(xpix),np.max(xpix)])
ax1.set_ylabel('y [arcsec]')
ax1.set_xlabel('x [arcsec]')
ax1.set_title('I')
cb = fig.colorbar(im1,orientation='vertical')
cb.set_label("$Jy$")
ax1.grid(False)

ax2=fig.add_subplot(222)
im2=ax2.imshow(Q_jy.astype(np.float64),cmap='plasma',extent=[np.min(ypix),np.max(ypix),np.min(xpix),np.max(xpix)])
ax2.set_ylabel('y [arcsec]')
ax2.set_xlabel('x [arcsec]')
ax2.set_title('Q')
cb = fig.colorbar(im2,orientation='vertical')
cb.set_label("$Jy$")
ax2.grid(False)

ax3=fig.add_subplot(223)
im3=ax3.imshow(U_jy.astype(np.float64),cmap='plasma',extent=[np.min(ypix),np.max(ypix),np.min(xpix),np.max(xpix)])
ax3.set_ylabel('y [arcsec]')
ax3.set_xlabel('x [arcsec]')
ax3.set_title('U')
cb = fig.colorbar(im3,orientation='vertical')
cb.set_label("$Jy$")
ax3.grid(False)

ax4=fig.add_subplot(224)
im4=ax4.imshow(V_jy.astype(np.float64),cmap='plasma',extent=[np.min(ypix),np.max(ypix),np.min(xpix),np.max(xpix)])
ax4.set_ylabel('y [arcsec]')
ax4.set_xlabel('x [arcsec]')
ax4.set_title('V')
cb = fig.colorbar(im4,orientation='vertical')
cb.set_label("$Jy$")
ax4.grid(False)
fig.subplots_adjust(hspace=0.1, wspace=0.25, top=0.9, right=0.95)
