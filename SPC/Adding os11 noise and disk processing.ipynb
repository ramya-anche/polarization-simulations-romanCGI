# %%
import disk_analysis as da
from astropy.io import fits
import numpy as np
import nmf_imaging
import matplotlib.pyplot as plt
from scipy.ndimage import zoom
from scipy.ndimage import rotate

datafile = '/Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Simulations_paper/SPC_band/spc_os11_speckle_noise.fits'
main_dir='/Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Simulations_paper/SPC_band/'
model='best_SED_DHS/'
disk_file_dir=main_dir+model
diskfile =disk_file_dir +'raw_emccd_I135.fits'
diskfile.split('_')
t=7

# %%
data = fits.getdata(datafile).astype(float)

dataID1 = da.spcprocess(data,1,diskfile=None)
dataID2 = da.spcprocess(data,2,diskfile=None)
dataID3 = da.spcprocess(data,3,diskfile=None)
dataID4 = da.spcprocess(data,4,diskfile=None)
dataID5 = da.spcprocess(data,5,diskfile=None)

# %% [markdown]
# # Grab the raw data with disk, don't photon count

# %%
df = diskfile
mode = 'Analog'
data = fits.getdata(datafile)

# -13 Deg if ID in [101,103,104,106,109,111,112,114]:
dataID101 = da.spcprocess(data,101,diskfile=df,mode=mode)
dataID103 = da.spcprocess(data,103,diskfile=df,mode=mode)
dataID104 = da.spcprocess(data,104,diskfile=df,mode=mode)
dataID106 = da.spcprocess(data,106,diskfile=df,mode=mode)
dataID109 = da.spcprocess(data,109,diskfile=df,mode=mode)
dataID111 = da.spcprocess(data,111,diskfile=df,mode=mode)
dataID112 = da.spcprocess(data,112,diskfile=df,mode=mode)
dataID114 = da.spcprocess(data,114,diskfile=df,mode=mode)

# +13 Deg ID in [100,102,105,107,108,110,113,115]:
dataID100 = da.spcprocess(data,100,diskfile=df,mode=mode)
dataID102 = da.spcprocess(data,102,diskfile=df,mode=mode)
dataID105 = da.spcprocess(data,105,diskfile=df,mode=mode)
dataID107 = da.spcprocess(data,107,diskfile=df,mode=mode)
dataID108 = da.spcprocess(data,108,diskfile=df,mode=mode)
dataID110 = da.spcprocess(data,110,diskfile=df,mode=mode)
dataID113 = da.spcprocess(data,113,diskfile=df,mode=mode)
dataID115 = da.spcprocess(data,115,diskfile=df,mode=mode)

# -13 Target NMF Box
rm11box_disk = np.zeros([8,181,181])
rm11box_disk[0] = dataID101
rm11box_disk[1] = dataID103
rm11box_disk[2] = dataID104
rm11box_disk[3] = dataID106
rm11box_disk[4] = dataID109
rm11box_disk[5] = dataID111
rm11box_disk[6] = dataID112
rm11box_disk[7] = dataID114

# +13 Target NMF Box
rp11box_disk = np.zeros([8,181,181])
rp11box_disk[0] = dataID100
rp11box_disk[1] = dataID102
rp11box_disk[2] = dataID105
rp11box_disk[3] = dataID107
rp11box_disk[4] = dataID108
rp11box_disk[5] = dataID110
rp11box_disk[6] = dataID113
rp11box_disk[7] = dataID115
# Out:
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)
# disk array shape =  (128, 128, 50)

# %%
import matplotlib.pyplot as plt
vmin = 0
vmax = 5
fig,ax = plt.subplots(ncols=8,nrows=2,figsize=[15,5])
plt.set_cmap('plasma')
ax[0,2].set_title('Target Data with Disks')
ax[0,0].imshow(rm11box_disk[0],vmin=vmin,vmax=vmax)
ax[0,1].imshow(rm11box_disk[1],vmin=vmin,vmax=vmax)
ax[0,2].imshow(rm11box_disk[2],vmin=vmin,vmax=vmax)
ax[0,3].imshow(rm11box_disk[3],vmin=vmin,vmax=vmax)
ax[0,4].imshow(rm11box_disk[4],vmin=vmin,vmax=vmax)
ax[0,5].imshow(rm11box_disk[5],vmin=vmin,vmax=vmax)
ax[0,6].imshow(rm11box_disk[6],vmin=vmin,vmax=vmax)
cmap = ax[0,7].imshow(rm11box_disk[7],vmin=vmin,vmax=vmax)
cbax = fig.add_axes([0.92,0.3,0.03,0.4])
ax[0,0].set_ylabel('-13 Target Data')
ax[1,0].imshow(rp11box_disk[0],vmin=vmin,vmax=vmax)
ax[1,1].imshow(rp11box_disk[1],vmin=vmin,vmax=vmax)
ax[1,2].imshow(rp11box_disk[2],vmin=vmin,vmax=vmax)
ax[1,3].imshow(rp11box_disk[3],vmin=vmin,vmax=vmax)
ax[1,4].imshow(rp11box_disk[4],vmin=vmin,vmax=vmax)
ax[1,5].imshow(rp11box_disk[5],vmin=vmin,vmax=vmax)
ax[1,6].imshow(rp11box_disk[6],vmin=vmin,vmax=vmax)
ax[1,7].imshow(rp11box_disk[7],vmin=vmin,vmax=vmax)
ax[1,0].set_ylabel('+13 Target Data')
cb = plt.colorbar(cmap,cax=cbax)
plt.show()

# %%
rM11_wd_nc = rm11box_disk
rP11_wd_nc = rp11box_disk

wdr = rP11_wd_nc + rotate(rM11_wd_nc,26,axes=[1,2],reshape=False)



from scipy.ndimage import rotate
import sys
#sys.path.append('/Users/polaris/opt/anaconda3/envs/astroconda/lib/python3.7/site-packages')
import sys
#sys.path.append('/home/ramya/anaconda3/lib/python3.8/site-packages')
import poppy



std_wd_raw = np.std(wdr,axis=0)
med_wd_raw = np.median(wdr,axis=0)


def array2poppyhdul(array,pixscal):
    
    # OpticStudio units are in waves, poppy likes .fits files
    hdu_p =fits.PrimaryHDU(array)
    hdul_p = fits.HDUList([hdu_p])
    hdul_p[0].header['PIXELSCL'] = pixscal
    hdul_p[0].header['BUNIT'] = 'arcsec'
    
    return hdul_p

radius,std_wd_raw_pr = poppy.radial_profile(array2poppyhdul(std_wd_raw,0.0210804))
radius,med_wd_raw_pr = poppy.radial_profile(array2poppyhdul(med_wd_raw,0.0210804))

# %%
vmin = 0
vmax = 5

# Grab mean in annulus
x = np.linspace(-1,1,181)
y = x
x,y = np.meshgrid(x,y)
r = np.sqrt(x**2 + y**2)

notmask = (r>0.75) | (r< 0.15)
replace = np.nan

med_wd_raw[notmask] = replace
std_wd_raw[notmask] = replace

fig,ax = plt.subplots(ncols=2,nrows=1,figsize=[4,4])
cmap = ax[0,0].imshow(med_wd_raw,vmin=vmin,vmax=vmax)
ax[0,1].imshow(std_wd_raw,vmin=vmin,vmax=vmax)
ax[0,0].set_ylabel('Processed - With disk')
ax[0,0].set_title('Median per pixel')
#ax[1,0].set_ylabel('Processed - Without disk')
#ax[0,1].set_title('StdDev per pixel')
ax[0,0].invert_yaxis()
cax = fig.add_axes([0.95, 0.3, 0.05, 0.5])
cax.set_title('phs/pix/sec')
fig.colorbar(cmap, cax=cax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [7], in <cell line: 17>()
#      14 std_wd_raw[notmask] = replace
#      16 fig,ax = plt.subplots(ncols=2,nrows=1,figsize=[4,4])
# ---> 17 cmap = ax[0,0].imshow(med_wd_raw,vmin=vmin,vmax=vmax)
#      18 ax[0,1].imshow(std_wd_raw,vmin=vmin,vmax=vmax)
#      19 ax[0,0].set_ylabel('Processed - With disk')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
fig_dir='/Users/polaris/Onedrive-UA/OneDrive - University of Arizona/Debris-Disk-Modelling/Debris-Disk-Modelling/Eps-eri-Roman_pol/Simulations_paper/Figures/'
fig=plt.figure(dpi=150)
ax2=plt.subplot(121)
im2=ax2.imshow(med_wd_raw,
               cmap='plasma')
ax2.tick_params(which='both', direction='in', width=0.5, labelsize=14)
ax2.invert_yaxis()
ax2.set_ylabel('pixels',fontsize=14)
ax2.set_xlabel('pixels',fontsize=14)
ax2.set_title("")
cb=plt.colorbar(im2,orientation='vertical',shrink=0.4)
cb.set_label("$ph/pix/sec$",fontsize=14)
cb.ax.tick_params(labelsize=13)
#fig.savefig(fig_dir+'model_image_4.pdf', format='pdf', bbox_inches='tight')

# %%
image0= fits.PrimaryHDU(med_wd_raw)
image0_hdul = fits.HDUList([image0])
image0_hdul.writeto(disk_file_dir+'med_wd_'+diskfile.split('_')[t],overwrite=True)
